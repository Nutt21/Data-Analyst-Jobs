# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid')

# %%
df = pd.read_csv("DataAnalyst.csv")
df
# Out:
#       Unnamed: 0                                          Job Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB

# %%
df.columns = df.columns.str.replace(' ', '_')
df
# Out:
#       Unnamed:_0                                          Job_Title  \
# 0              0  Data Analyst, Center on Immigration and Justic...
# 1              1                               Quality Data Analyst
# 2              2  Senior Data Analyst, Insights & Analytics Team...
# 3              3                                       Data Analyst
# 4              4                             Reporting Data Analyst
# ...          ...                                                ...
# 2248        2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249        2249              Senior Data Analyst (Corporate Audit)
# 2250        2250  Technical Business Analyst (SQL, Data analytic...
# 2251        2251                Data Analyst 3, Customer Experience
# 2252        2252                        Senior Quality Data Analyst
#
#                   Salary_Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job_Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company_Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type_of_ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 16 columns]

# %%
df.drop(["Unnamed:_0", "Job_Description"], inplace=True, axis=1)
df
# Out:
#                                               Job_Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary_Estimate  Rating  \
# 0      $37K-$66K (Glassdoor est.)     3.2
# 1      $37K-$66K (Glassdoor est.)     3.8
# 2      $37K-$66K (Glassdoor est.)     3.4
# 3      $37K-$66K (Glassdoor est.)     4.1
# 4      $37K-$66K (Glassdoor est.)     3.9
# ...                           ...     ...
# 2248  $78K-$104K (Glassdoor est.)     2.5
# 2249  $78K-$104K (Glassdoor est.)     2.9
# 2250  $78K-$104K (Glassdoor est.)    -1.0
# 2251  $78K-$104K (Glassdoor est.)     3.1
# 2252  $78K-$104K (Glassdoor est.)     3.4
#
#                                  Company_Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type_of_ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply
# 0                                                    -1       True
# 1                                                    -1         -1
# 2                                               GoDaddy         -1
# 3                                                    -1         -1
# 4                                            DraftKings       True
# ...                                                 ...        ...
# 2248                                                 -1         -1
# 2249                     Avnet, Ingram Micro, Tech Data         -1
# 2250                                                 -1         -1
# 2251                                                 -1         -1
# 2252  Centura Health, HealthONE, Denver Health and H...         -1
#
# [2253 rows x 14 columns]

# %%
df["Rated"] = pd.cut(df.Rating, bins=[0, 2.0, 3.0, 4.0, 5], labels=["Bad", "NotBad", "Good", "Excellent"])
df
# Out:
#                                               Job_Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary_Estimate  Rating  \
# 0      $37K-$66K (Glassdoor est.)     3.2
# 1      $37K-$66K (Glassdoor est.)     3.8
# 2      $37K-$66K (Glassdoor est.)     3.4
# 3      $37K-$66K (Glassdoor est.)     4.1
# 4      $37K-$66K (Glassdoor est.)     3.9
# ...                           ...     ...
# 2248  $78K-$104K (Glassdoor est.)     2.5
# 2249  $78K-$104K (Glassdoor est.)     2.9
# 2250  $78K-$104K (Glassdoor est.)    -1.0
# 2251  $78K-$104K (Glassdoor est.)     3.1
# 2252  $78K-$104K (Glassdoor est.)     3.4
#
#                                  Company_Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type_of_ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply      Rated
# 0                                                    -1       True       Good
# 1                                                    -1         -1       Good
# 2                                               GoDaddy         -1       Good
# 3                                                    -1         -1  Excellent
# 4                                            DraftKings       True       Good
# ...                                                 ...        ...        ...
# 2248                                                 -1         -1     NotBad
# 2249                     Avnet, Ingram Micro, Tech Data         -1     NotBad
# 2250                                                 -1         -1        NaN
# 2251                                                 -1         -1       Good
# 2252  Centura Health, HealthONE, Denver Health and H...         -1       Good
#
# [2253 rows x 15 columns]

# %%
df.Easy_Apply.fillna(value=False, inplace=True)
df.Competitors.fillna(value=0, inplace=True)
df.Salary_Estimate.dropna(inplace=True)
df.Rating.fillna(value=df.Rating.mean(), inplace=True)
df.Industry.fillna(value='Others', inplace=True)
df.Revenue.fillna(value='Unknown', inplace=True)
df.Founded.fillna(value = df.Founded.mean(),inplace= True)
df.Founded = df.Founded.astype(int)

# %%
split_sal = df["Salary_Estimate"].str.split('-', expand=True)
df["Min_salary_US_K"] = pd.to_numeric(split_sal[0].str.extract('(\d+)', expand=False))
df["Max_salary_US_K"] = pd.to_numeric(split_sal[1].str.extract('(\d+)', expand=False))
df["Average_Salary_US_K"] = (df["Min_salary_US_K"] + df["Max_salary_US_K"])/2
df
# Out:
#                                               Job_Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary_Estimate  Rating  \
# 0      $37K-$66K (Glassdoor est.)     3.2
# 1      $37K-$66K (Glassdoor est.)     3.8
# 2      $37K-$66K (Glassdoor est.)     3.4
# 3      $37K-$66K (Glassdoor est.)     4.1
# 4      $37K-$66K (Glassdoor est.)     3.9
# ...                           ...     ...
# 2248  $78K-$104K (Glassdoor est.)     2.5
# 2249  $78K-$104K (Glassdoor est.)     2.9
# 2250  $78K-$104K (Glassdoor est.)    -1.0
# 2251  $78K-$104K (Glassdoor est.)     3.1
# 2252  $78K-$104K (Glassdoor est.)     3.4
#
#                                  Company_Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type_of_ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply      Rated  \
# 0                                                    -1       True       Good
# 1                                                    -1         -1       Good
# 2                                               GoDaddy         -1       Good
# 3                                                    -1         -1  Excellent
# 4                                            DraftKings       True       Good
# ...                                                 ...        ...        ...
# 2248                                                 -1         -1     NotBad
# 2249                     Avnet, Ingram Micro, Tech Data         -1     NotBad
# 2250                                                 -1         -1        NaN
# 2251                                                 -1         -1       Good
# 2252  Centura Health, HealthONE, Denver Health and H...         -1       Good
#
#       Min_salary_US_K  Max_salary_US_K  Average_Salary_US_K
# 0                37.0               66                 51.5
# 1                37.0               66                 51.5
# 2                37.0               66                 51.5
# 3                37.0               66                 51.5
# 4                37.0               66                 51.5
# ...               ...              ...                  ...
# 2248             78.0              104                 91.0
# 2249             78.0              104                 91.0
# 2250             78.0              104                 91.0
# 2251             78.0              104                 91.0
# 2252             78.0              104                 91.0
#
# [2253 rows x 18 columns]

# %%
split_c_name = df["Company_Name"].str.split("\n", expand=True)
df.Company_Name = split_c_name[0]
df
# Out:
#                                               Job_Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary_Estimate  Rating                        Company_Name  \
# 0      $37K-$66K (Glassdoor est.)     3.2           Vera Institute of Justice
# 1      $37K-$66K (Glassdoor est.)     3.8  Visiting Nurse Service of New York
# 2      $37K-$66K (Glassdoor est.)     3.4                         Squarespace
# 3      $37K-$66K (Glassdoor est.)     4.1                            Celerity
# 4      $37K-$66K (Glassdoor est.)     3.9                             FanDuel
# ...                           ...     ...                                 ...
# 2248  $78K-$104K (Glassdoor est.)     2.5                       Avacend, Inc.
# 2249  $78K-$104K (Glassdoor est.)     2.9                   Arrow Electronics
# 2250  $78K-$104K (Glassdoor est.)    -1.0                            Spiceorb
# 2251  $78K-$104K (Glassdoor est.)     3.1         Contingent Network Services
# 2252  $78K-$104K (Glassdoor est.)     3.4                          SCL Health
#
#             Location      Headquarters                    Size  Founded  \
# 0       New York, NY      New York, NY    201 to 500 employees     1961
# 1       New York, NY      New York, NY        10000+ employees     1893
# 2       New York, NY      New York, NY  1001 to 5000 employees     2003
# 3       New York, NY        McLean, VA    201 to 500 employees     2002
# 4       New York, NY      New York, NY   501 to 1000 employees     2009
# ...              ...               ...                     ...      ...
# 2248      Denver, CO    Alpharetta, GA     51 to 200 employees       -1
# 2249  Centennial, CO    Centennial, CO        10000+ employees     1935
# 2250      Denver, CO                -1                      -1       -1
# 2251  Centennial, CO  West Chester, OH    201 to 500 employees     1984
# 2252  Broomfield, CO    Broomfield, CO        10000+ employees     1864
#
#                    Type_of_ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue  \
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
#                                             Competitors Easy_Apply      Rated  \
# 0                                                    -1       True       Good
# 1                                                    -1         -1       Good
# 2                                               GoDaddy         -1       Good
# 3                                                    -1         -1  Excellent
# 4                                            DraftKings       True       Good
# ...                                                 ...        ...        ...
# 2248                                                 -1         -1     NotBad
# 2249                     Avnet, Ingram Micro, Tech Data         -1     NotBad
# 2250                                                 -1         -1        NaN
# 2251                                                 -1         -1       Good
# 2252  Centura Health, HealthONE, Denver Health and H...         -1       Good
#
#       Min_salary_US_K  Max_salary_US_K  Average_Salary_US_K
# 0                37.0               66                 51.5
# 1                37.0               66                 51.5
# 2                37.0               66                 51.5
# 3                37.0               66                 51.5
# 4                37.0               66                 51.5
# ...               ...              ...                  ...
# 2248             78.0              104                 91.0
# 2249             78.0              104                 91.0
# 2250             78.0              104                 91.0
# 2251             78.0              104                 91.0
# 2252             78.0              104                 91.0
#
# [2253 rows x 18 columns]

# %%
state = df.Location.str.split(',', expand=True)
state
# Out:
#                0    1     2
# 0       New York   NY  None
# 1       New York   NY  None
# 2       New York   NY  None
# 3       New York   NY  None
# 4       New York   NY  None
# ...          ...  ...   ...
# 2248      Denver   CO  None
# 2249  Centennial   CO  None
# 2250      Denver   CO  None
# 2251  Centennial   CO  None
# 2252  Broomfield   CO  None
#
# [2253 rows x 3 columns]

# %%
state_h = df.Headquarters.str.split(',', expand=True)
state_h
# Out:
#                  0     1     2
# 0         New York    NY  None
# 1         New York    NY  None
# 2         New York    NY  None
# 3           McLean    VA  None
# 4         New York    NY  None
# ...            ...   ...   ...
# 2248    Alpharetta    GA  None
# 2249    Centennial    CO  None
# 2250            -1  None  None
# 2251  West Chester    OH  None
# 2252    Broomfield    CO  None
#
# [2253 rows x 3 columns]

# %%
df['Location_State'] = state[1]
df['Hq_state'] = state_h[1]

# %%
df['Salary_Range']=pd.cut(df.Average_Salary_US_K, bins= [0 , 50 ,100, 150] , labels = ['Poor' , 'Medium','Good'])
df.head()
# Out:
#                                            Job_Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary_Estimate  Rating                        Company_Name  \
# 0  $37K-$66K (Glassdoor est.)     3.2           Vera Institute of Justice
# 1  $37K-$66K (Glassdoor est.)     3.8  Visiting Nurse Service of New York
# 2  $37K-$66K (Glassdoor est.)     3.4                         Squarespace
# 3  $37K-$66K (Glassdoor est.)     4.1                            Celerity
# 4  $37K-$66K (Glassdoor est.)     3.9                             FanDuel
#
#        Location  Headquarters                    Size  Founded  \
# 0  New York, NY  New York, NY    201 to 500 employees     1961
# 1  New York, NY  New York, NY        10000+ employees     1893
# 2  New York, NY  New York, NY  1001 to 5000 employees     2003
# 3  New York, NY    McLean, VA    201 to 500 employees     2002
# 4  New York, NY  New York, NY   501 to 1000 employees     2009
#
#                 Type_of_ownership                          Industry  ...  \
# 0          Nonprofit Organization                 Social Assistance  ...
# 1          Nonprofit Organization  Health Care Services & Hospitals  ...
# 2               Company - Private                          Internet  ...
# 3  Subsidiary or Business Segment                       IT Services  ...
# 4               Company - Private               Sports & Recreation  ...
#
#                       Revenue Competitors Easy_Apply      Rated  \
# 0  $100 to $500 million (USD)          -1       True       Good
# 1      $2 to $5 billion (USD)          -1         -1       Good
# 2    Unknown / Non-Applicable     GoDaddy         -1       Good
# 3   $50 to $100 million (USD)          -1         -1  Excellent
# 4  $100 to $500 million (USD)  DraftKings       True       Good
#
#   Min_salary_US_K  Max_salary_US_K  Average_Salary_US_K  Location_State  \
# 0            37.0               66                 51.5              NY
# 1            37.0               66                 51.5              NY
# 2            37.0               66                 51.5              NY
# 3            37.0               66                 51.5              NY
# 4            37.0               66                 51.5              NY
#
#   Hq_state Salary_Range
# 0       NY       Medium
# 1       NY       Medium
# 2       NY       Medium
# 3       VA       Medium
# 4       NY       Medium
#
# [5 rows x 21 columns]

# %%
df.sort_values(by = 'Max_salary_US_K', ascending = False).head()
# Out:
#                                    Job_Title               Salary_Estimate  \
# 1471                            Data Analyst  $110K-$190K (Glassdoor est.)
# 1485                Data Analyst (SQL, Hive)  $110K-$190K (Glassdoor est.)
# 1494                            Data Analyst  $110K-$190K (Glassdoor est.)
# 1472          Data Analyst, Product Insights  $110K-$190K (Glassdoor est.)
# 1493  Data Analyst with Data Mapping and API  $110K-$190K (Glassdoor est.)
#
#       Rating      Company_Name          Location   Headquarters  \
# 1471     4.0          LeanData   Santa Clara, CA  Sunnyvale, CA
# 1485     4.4             Ursus    Menlo Park, CA       Reno, NV
# 1494     3.9       Kaygen Inc.      San Jose, CA     Irvine, CA
# 1472     3.3           Alteryx  Redwood City, CA     Irvine, CA
# 1493    -1.0  Xcutives.com Inc      San Jose, CA             -1
#
#                         Size  Founded  Type_of_ownership  \
# 1471     51 to 200 employees     2012  Company - Private
# 1485       1 to 50 employees       -1  Company - Private
# 1494       1 to 50 employees       -1  Company - Private
# 1472  1001 to 5000 employees     1997   Company - Public
# 1493                      -1       -1                 -1
#
#                                      Industry  ...  \
# 1471  Enterprise Software & Network Solutions  ...
# 1485                              IT Services  ...
# 1494                               Consulting  ...
# 1472  Enterprise Software & Network Solutions  ...
# 1493                                       -1  ...
#
#                          Revenue                                 Competitors  \
# 1471    $10 to $25 million (USD)                                          -1
# 1485    Unknown / Non-Applicable  TEKsystems, Kforce, Milestone Technologies
# 1494      $1 to $5 million (USD)                                          -1
# 1472  $100 to $500 million (USD)                                          -1
# 1493                          -1                                          -1
#
#      Easy_Apply      Rated Min_salary_US_K  Max_salary_US_K  \
# 1471         -1       Good           110.0              190
# 1485         -1  Excellent           110.0              190
# 1494         -1       Good           110.0              190
# 1472         -1       Good           110.0              190
# 1493         -1        NaN           110.0              190
#
#       Average_Salary_US_K  Location_State Hq_state Salary_Range
# 1471                150.0              CA       CA         Good
# 1485                150.0              CA       NV         Good
# 1494                150.0              CA       CA         Good
# 1472                150.0              CA       CA         Good
# 1493                150.0              CA     None         Good
#
# [5 rows x 21 columns]

# %%
top_sal = df[df["Max_salary_US_K"] == 190]
top_sal.sort_values(by= 'Rating', inplace=True)
top_sal.tail()
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                               Job_Title               Salary_Estimate  Rating  \
# 1485           Data Analyst (SQL, Hive)  $110K-$190K (Glassdoor est.)     4.4
# 1486  Data Analyst, Autonomy Operations  $110K-$190K (Glassdoor est.)     4.4
# 1468                       Data Analyst  $110K-$190K (Glassdoor est.)     4.5
# 1469             Senior HR Data Analyst  $110K-$190K (Glassdoor est.)     4.6
# 1484           AI Insights Data Analyst  $110K-$190K (Glassdoor est.)     5.0
#
#          Company_Name           Location       Headquarters  \
# 1485            Ursus     Menlo Park, CA           Reno, NV
# 1486             Nuro  Mountain View, CA  Mountain View, CA
# 1468  OSI Engineering         Newark, CA       Campbell, CA
# 1469           NVIDIA    Santa Clara, CA    Santa Clara, CA
# 1484        Moveworks  Mountain View, CA  Mountain View, CA
#
#                       Size  Founded  Type_of_ownership  \
# 1485     1 to 50 employees       -1  Company - Private
# 1486  201 to 500 employees     2016  Company - Private
# 1468   51 to 200 employees     2010  Company - Private
# 1469      10000+ employees     1993   Company - Public
# 1484   51 to 200 employees     2016  Company - Private
#
#                                      Industry  ...                   Revenue  \
# 1485                              IT Services  ...  Unknown / Non-Applicable
# 1486             Computer Hardware & Software  ...  Unknown / Non-Applicable
# 1468                   Staffing & Outsourcing  ...  $25 to $50 million (USD)
# 1469             Computer Hardware & Software  ...   $5 to $10 billion (USD)
# 1484  Enterprise Software & Network Solutions  ...  Unknown / Non-Applicable
#
#                                      Competitors Easy_Apply      Rated  \
# 1485  TEKsystems, Kforce, Milestone Technologies         -1  Excellent
# 1486                                          -1         -1  Excellent
# 1468                                          -1       True  Excellent
# 1469                                          -1         -1  Excellent
# 1484                                          -1       True  Excellent
#
#      Min_salary_US_K  Max_salary_US_K  Average_Salary_US_K  Location_State  \
# 1485           110.0              190                150.0              CA
# 1486           110.0              190                150.0              CA
# 1468           110.0              190                150.0              CA
# 1469           110.0              190                150.0              CA
# 1484           110.0              190                150.0              CA
#
#      Hq_state Salary_Range
# 1485       NV         Good
# 1486       CA         Good
# 1468       CA         Good
# 1469       CA         Good
# 1484       CA         Good
#
# [5 rows x 21 columns]

# %%
top_sal.Company_Name.unique()
# Out:
# array(['Xcutives.com Inc', 'Bandai Namco Entertainment America',
#        'Logic Planet', 'Alteryx', 'Kelly', 'Tesla Motors', 'L&T Infotech',
#        'ICONMA', 'Iconma, L.L.C.', 'Randstad', 'IntraEdge', 'Enjoy',
#        'Kaygen Inc.', 'Netflix', 'TalentBurst, Inc.', 'Diverse Lynx',
#        'Joomag, Inc.', 'Risk Management Solutions (RMS)', 'Cognoa',
#        'Zipongo', 'Connor Group', 'LeanData', 'BayOne Solutions', 'Ursus',
#        'Nuro', 'OSI Engineering', 'NVIDIA', 'Moveworks'], dtype=object)

# %%
top_sal.drop([1479,1493], inplace=True)
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/core/frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
fig= plt.gcf();
fig.set_size_inches(15,7);
sns.barplot( x='Company_Name', y='Rating', data = top_sal,
            dodge=False, hue = 'Rated').set_title('Companies having the highest salary');
plt.xticks(rotation=80);
plt.xlabel('Company Name');

# %%
fig= plt.gcf();
fig.set_size_inches(13,7);
sns.barplot( y='Job_Title',x='Rating', data = top_sal,
            dodge=False, ci= None, palette= 'Reds', orient = 'h').set_title('Job Title with the highest salary');
plt.xticks(rotation=80);
plt.xlabel('Job Title');

# %%
top_rated = df[df["Rating"] == 5.0]
top_rated.sort_values(by="Average_Salary_US_K")
top_rated
# Out:
#                                               Job_Title  \
# 26                 Data + Business Intelligence Analyst
# 42                                         Data Analyst
# 78                                         Data Analyst
# 81                                         Data Analyst
# 106                                Data/Systems Analyst
# ...                                                 ...
# 2206                             Marketing Data Analyst
# 2207                                       Data Analyst
# 2220  MDG Functional Data Analyst-Greenwood Village, CO
# 2221                                Data Analyst Junior
# 2226                              Data Analyst - Junior
#
#                   Salary_Estimate  Rating                      Company_Name  \
# 26     $37K-$66K (Glassdoor est.)     5.0                          Duolingo
# 42     $46K-$87K (Glassdoor est.)     5.0                  Whip Media Group
# 78     $51K-$88K (Glassdoor est.)     5.0               Mulberry Technology
# 81     $51K-$88K (Glassdoor est.)     5.0                         EDO, Inc.
# 106    $51K-$87K (Glassdoor est.)     5.0  Crossfire Consulting Corporation
# ...                           ...     ...                               ...
# 2206   $49K-$91K (Glassdoor est.)     5.0                Goldstone Partners
# 2207   $49K-$91K (Glassdoor est.)     5.0               xentity corporation
# 2220  $57K-$100K (Glassdoor est.)     5.0                   Georgia IT Inc.
# 2221  $57K-$100K (Glassdoor est.)     5.0  Staffigo Technical Services, LLC
# 2226  $57K-$100K (Glassdoor est.)     5.0  Staffigo Technical Services, LLC
#
#                              Location           Headquarters  \
# 26                       New York, NY         Pittsburgh, PA
# 42                       New York, NY       Santa Monica, CA
# 78                       New York, NY  New York, NY (US), NY
# 81                       New York, NY        Los Angeles, CA
# 106                      New York, NY   Yorktown Heights, NY
# ...                               ...                    ...
# 2206                      Boulder, CO             Denver, CO
# 2207                       Denver, CO           Lakewood, CO
# 2220  Greenwood Village, Arapahoe, CO         Alpharetta, GA
# 2221                       Denver, CO          Woodridge, IL
# 2226                       Denver, CO          Woodridge, IL
#
#                       Size  Founded  Type_of_ownership  \
# 26    201 to 500 employees     2011  Company - Private
# 42     51 to 200 employees     2016  Company - Private
# 78       1 to 50 employees       -1  Company - Private
# 81       1 to 50 employees       -1  Company - Private
# 106    51 to 200 employees       -1  Company - Private
# ...                    ...      ...                ...
# 2206     1 to 50 employees       -1  Company - Private
# 2207   51 to 200 employees     2001  Company - Private
# 2220     1 to 50 employees       -1  Company - Private
# 2221   51 to 200 employees     2008  Company - Private
# 2226   51 to 200 employees     2008  Company - Private
#
#                     Industry  ...                     Revenue Competitors  \
# 26                  Internet  ...    $10 to $25 million (USD)          -1
# 42                        -1  ...    Unknown / Non-Applicable          -1
# 78                        -1  ...    Unknown / Non-Applicable          -1
# 81                  Internet  ...    Unknown / Non-Applicable          -1
# 106               Consulting  ...     $5 to $10 million (USD)          -1
# ...                      ...  ...                         ...         ...
# 2206  Staffing & Outsourcing  ...  Less than $1 million (USD)          -1
# 2207             IT Services  ...     $5 to $10 million (USD)          -1
# 2220                      -1  ...  Less than $1 million (USD)          -1
# 2221             IT Services  ...   $50 to $100 million (USD)          -1
# 2226             IT Services  ...   $50 to $100 million (USD)          -1
#
#      Easy_Apply      Rated Min_salary_US_K  Max_salary_US_K  \
# 26           -1  Excellent            37.0               66
# 42           -1  Excellent            46.0               87
# 78           -1  Excellent            51.0               88
# 81           -1  Excellent            51.0               88
# 106          -1  Excellent            51.0               87
# ...         ...        ...             ...              ...
# 2206         -1  Excellent            49.0               91
# 2207         -1  Excellent            49.0               91
# 2220         -1  Excellent            57.0              100
# 2221         -1  Excellent            57.0              100
# 2226         -1  Excellent            57.0              100
#
#       Average_Salary_US_K  Location_State  Hq_state Salary_Range
# 26                   51.5              NY        PA       Medium
# 42                   66.5              NY        CA       Medium
# 78                   69.5              NY   NY (US)       Medium
# 81                   69.5              NY        CA       Medium
# 106                  69.0              NY        NY       Medium
# ...                   ...             ...       ...          ...
# 2206                 70.0              CO        CO       Medium
# 2207                 70.0              CO        CO       Medium
# 2220                 78.5        Arapahoe        GA       Medium
# 2221                 78.5              CO        IL       Medium
# 2226                 78.5              CO        IL       Medium
#
# [131 rows x 21 columns]

# %%
top_rated.Company_Name.unique()
# Out:
# array(['Duolingo', 'Whip Media Group', 'Mulberry Technology', 'EDO, Inc.',
#        'Crossfire Consulting Corporation', 'Averity',
#        'Staffigo Technical Services, LLC', 'VISTRADA', 'Earnest Research',
#        'Professional Resource Group', 'Blue Rock Consulting',
#        'Creative Data Resources', 'ITech Recruiting', 'Resiliency LLC',
#        'Counter Threat Solutions', 'Wellth Inc.',
#        'First Professional Services', 'Dot818', 'Tilde Staff Inc.',
#        'Scale Media', 'LEAPROS', 'Connect International', 'WB Technology',
#        'Pddn', 'Georgia IT Inc.', 'Quinn Group', 'LaBine & Associates',
#        'Centric Consulting', '1872 Consulting', 'Foresight ROI', 'Jobot',
#        'Xeris Pharmaceuticals, Inc.', 'Purity Technology LLC',
#        'Crawford Thomas Recruiting', 'Nucleusteq', 'Keen360, Inc.',
#        'Cambridge Advisory Group', 'The Rock Church', 'PeopleFun',
#        'PriceSenz', 'Moveworks', 'TechNet Inc.', 'ARC Group',
#        'American Recruiting & Consulting Group', 'Company Confidenital',
#        'Revel IT', 'Payzer', 'Trivest', 'PCR Staffing', 'LaunchDarkly',
#        'Elevate Labs', 'Wilbur Labs', 'Priceonomics',
#        'Turn/River Capital', 'Softova Inc', 'addastaff',
#        'Concept Software & Services Inc', 'Strive Health',
#        'Edison Software, Inc.', 'xentity corporation',
#        'Goldstone Partners'], dtype=object)

# %%
fig = plt.gcf()
plt.figure(figsize=(25,7))
sns.barplot(x="Company_Name", y="Average_Salary_US_K", data= top_rated, palette="copper", ci=None)
plt.title("Figure:\n\n Companies having highest rating")
plt.xticks(rotation=90)
plt.xlabel('Company_Name')
plt.ylabel("Average_Salary")
# Out:
# Text(0, 0.5, 'Average_Salary')

# %%
c = df.groupby('Location_State').count()
loc_st = c[c['Job_Title']>20]
others = c[c['Job_Title']<20]
loc_st.loc['Others'] = pd.Series(others.sum())
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
loc_st.reset_index(inplace=True)
loc_st.sort_values(by='Job_Title', inplace=True)
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
state[[0,1]]
# Out:
#                0    1
# 0       New York   NY
# 1       New York   NY
# 2       New York   NY
# 3       New York   NY
# 4       New York   NY
# ...          ...  ...
# 2248      Denver   CO
# 2249  Centennial   CO
# 2250      Denver   CO
# 2251  Centennial   CO
# 2252  Broomfield   CO
#
# [2253 rows x 2 columns]

# %%
sz = df.groupby('Size').count()
sz.sort_values(by='Job_Title', ascending=False, inplace=True )
sz.reset_index(inplace=True)
sz
# Out:
#                       Size  Job_Title  Salary_Estimate  Rating  Company_Name  \
# 0      51 to 200 employees        421              421     421           421
# 1         10000+ employees        375              375     375           375
# 2   1001 to 5000 employees        348              348     348           348
# 3        1 to 50 employees        347              347     347           347
# 4     201 to 500 employees        249              249     249           249
# 5    501 to 1000 employees        211              211     211           211
# 6                       -1        163              163     163           162
# 7  5001 to 10000 employees         97               97      97            97
# 8                  Unknown         42               42      42            42
#
#    Location  Headquarters  Founded  Type_of_ownership  Industry  ...  Revenue  \
# 0       421           421      421                421       421  ...      421
# 1       375           375      375                375       375  ...      375
# 2       348           348      348                348       348  ...      348
# 3       347           347      347                347       347  ...      347
# 4       249           249      249                249       249  ...      249
# 5       211           211      211                211       211  ...      211
# 6       163           163      163                163       163  ...      163
# 7        97            97       97                 97        97  ...       97
# 8        42            42       42                 42        42  ...       42
#
#    Competitors  Easy_Apply  Rated  Min_salary_US_K  Max_salary_US_K  \
# 0          421         421    397              420              421
# 1          375         375    375              375              375
# 2          348         348    347              348              348
# 3          347         347    288              347              347
# 4          249         249    246              249              249
# 5          211         211    211              211              211
# 6          163         163      0              163              163
# 7           97          97     97               97               97
# 8           42          42     20               42               42
#
#    Average_Salary_US_K  Location_State  Hq_state  Salary_Range
# 0                  420             421       420           420
# 1                  375             375       375           375
# 2                  348             348       348           348
# 3                  347             347       345           347
# 4                  249             249       249           249
# 5                  211             211       207           211
# 6                  163             163         0           163
# 7                   97              97        97            97
# 8                   42              42        40            42
#
# [9 rows x 21 columns]

# %%
sz.Size.unique()
# Out:
# array(['51 to 200 employees', '10000+ employees',
#        '1001 to 5000 employees', '1 to 50 employees',
#        '201 to 500 employees', '501 to 1000 employees', '-1',
#        '5001 to 10000 employees', 'Unknown'], dtype=object)

# %%
fig = plt.gcf()
plt.figure(figsize=(25, 7))
sns.barplot(y='Job_Title', x='Size', palette='autumn', data=sz)
plt.title("Figure:6 \n\n According to jobs of the size company", fontsize=25)
plt.xticks(rotation =80)
plt.ylabel('Available jobs')
plt.xlabel('Size')
# Out:
# Text(0.5, 0, 'Size')

# %%
fig = plt.gcf()
fig.set_size_inches(20, 7)
sns.swarmplot(x='Size', y='Average_Salary_US_K', hue='Rated', data=df, palette= 'winter')
plt.title("Available jobs according to the of company")
plt.xticks(rotation=80)
plt.xlabel("Size of the company")
plt.ylabel("Average salary")
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 8.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# Text(0, 0.5, 'Average salary')

# %%
c = df.groupby('Industry').count().sort_values(by= 'Job_Title')
ind = c[c.Job_Title >2]
others = c[c.Job_Title < 2.1]
ind.loc['Others'] = pd.Series(others.sum())
ind.reset_index(inplace=True)
ind.copy(deep=True)
ind.sort_values(by='Job_Title', inplace=True)
ind
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                              Industry  Job_Title  Salary_Estimate  Rating  \
# 0              Preschool & Child Care          3                3       3
# 1                        Gas Stations          3                3       3
# 2                 Other Retail Stores          3                3       3
# 3    Health Fundraising Organizations          3                3       3
# 4   General Merchandise & Superstores          3                3       3
# ..                                ...        ...              ...     ...
# 60                         Consulting        111              111     111
# 61   Health Care Services & Hospitals        151              151     151
# 62             Staffing & Outsourcing        323              323     323
# 63                        IT Services        325              325     325
# 64                                 -1        353              353     353
#
#     Company_Name  Location  Headquarters  Size  Founded  Type_of_ownership  \
# 0              3         3             3     3        3                  3
# 1              3         3             3     3        3                  3
# 2              3         3             3     3        3                  3
# 3              3         3             3     3        3                  3
# 4              3         3             3     3        3                  3
# ..           ...       ...           ...   ...      ...                ...
# 60           111       111           111   111      111                111
# 61           151       151           151   151      151                151
# 62           323       323           323   323      323                323
# 63           325       325           325   325      325                325
# 64           352       353           353   353      353                353
#
#     ...  Revenue  Competitors  Easy_Apply  Rated  Min_salary_US_K  \
# 0   ...        3            3           3      3                3
# 1   ...        3            3           3      3                3
# 2   ...        3            3           3      3                3
# 3   ...        3            3           3      1                3
# 4   ...        3            3           3      3                3
# ..  ...      ...          ...         ...    ...              ...
# 60  ...      111          111         111    110              111
# 61  ...      151          151         151    150              151
# 62  ...      323          323         323    320              322
# 63  ...      325          325         325    317              325
# 64  ...      353          353         353    121              353
#
#     Max_salary_US_K  Average_Salary_US_K  Location_State  Hq_state  \
# 0                 3                    3               3         3
# 1                 3                    3               3         3
# 2                 3                    3               3         3
# 3                 3                    3               3         3
# 4                 3                    3               3         3
# ..              ...                  ...             ...       ...
# 60              111                  111             111       111
# 61              151                  151             151       151
# 62              323                  322             323       319
# 63              325                  325             325       324
# 64              353                  353             353       186
#
#     Salary_Range
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3
# ..           ...
# 60           111
# 61           151
# 62           322
# 63           325
# 64           353
#
# [66 rows x 21 columns]

# %%
ind.Industry.unique()
# Out:
# array(['Preschool & Child Care', 'Gas Stations', 'Other Retail Stores',
#        'Health Fundraising Organizations',
#        'General Merchandise & Superstores', 'Gambling',
#        'Grocery Stores & Supermarkets',
#        'Transportation Equipment Manufacturing', 'Vehicle Dealers',
#        'Education Training Services', 'Sports & Recreation',
#        'Transportation Management', 'Oil & Gas Services',
#        'Automotive Parts & Accessories Stores', 'Legal',
#        'Membership Organizations', 'Insurance Agencies & Brokerages',
#        'Publishing', 'Health Care Products Manufacturing',
#        'Casual Restaurants', 'Cable, Internet & Telephone Providers',
#        'Home Centers & Hardware Stores',
#        'Department, Clothing, & Shoe Stores',
#        'Electrical & Electronic Manufacturing', 'Brokerage Services',
#        'Commercial Equipment Repair & Maintenance', 'Wholesale',
#        'K-12 Education', 'Venture Capital & Private Equity',
#        'Telecommunications Services', 'Food & Beverage Manufacturing',
#        'Motion Picture Production & Distribution', 'Energy',
#        'Industrial Manufacturing', 'Construction',
#        'Municipal Governments', 'Consumer Products Manufacturing',
#        'Financial Transaction Processing',
#        'TV Broadcast & Cable Networks', 'Research & Development',
#        'Real Estate', 'Federal Agencies',
#        'Architectural & Engineering Services',
#        'Health, Beauty, & Fitness', 'Logistics & Supply Chain', 'Lending',
#        'State & Regional Agencies', 'Video Games', 'Aerospace & Defense',
#        'Social Assistance', 'Biotech & Pharmaceuticals', 'Others',
#        'Accounting', 'Colleges & Universities', 'Insurance Carriers',
#        'Banks & Credit Unions', 'Advertising & Marketing', 'Internet',
#        'Enterprise Software & Network Solutions',
#        'Investment Banking & Asset Management',
#        'Computer Hardware & Software', 'Consulting',
#        'Health Care Services & Hospitals', 'Staffing & Outsourcing',
#        'IT Services', '-1'], dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(20, 10)
sns.barplot(x='Industry', y='Job_Title', data=ind, ci= None, palette='autumn').set_title('Available jobs according to the industry');
plt.xticks(rotation= 90)
plt.xlabel('Industry Name')
plt.ylabel('No.of jobs available')
# Out:
# Text(0, 0.5, 'No.of jobs available')

# %%
jt = df.groupby('Job_Title').count().sort_values(by='Salary_Estimate', ascending=False)
jt.reset_index(inplace=True)

# %%
jt.Job_Title.unique()
# Out:
# array(['Data Analyst', 'Senior Data Analyst', 'Junior Data Analyst', ...,
#        'Data Analyst- San Antonio, Des Moines',
#        'Data Analyst- Growth Operations',
#        '【1yr OPT+Intern】Data Analyst 保实习保就业'], dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(15,9)
sns.barplot(x='Salary_Estimate', y='Job_Title', data=jt.head(30), palette='winter',orient='h', ci=None,).set_title('Most popular job titles')
plt.xlabel('No of jobs available')
plt.ylabel('Job title')
plt.xticks(rotation=90)
# Out:
# (array([  0.,  50., 100., 150., 200., 250., 300., 350., 400., 450.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
rev = df.groupby('Revenue').count().sort_values(by='Job_Title', ascending=False)
rev.reset_index(inplace=True)
rev
# Out:
#                              Revenue  Job_Title  Salary_Estimate  Rating  \
# 0           Unknown / Non-Applicable        615              615     615
# 1         $100 to $500 million (USD)        218              218     218
# 2          $50 to $100 million (USD)        199              199     199
# 3                 $10+ billion (USD)        189              189     189
# 4                                 -1        163              163     163
# 5           $10 to $25 million (USD)        132              132     132
# 6             $2 to $5 billion (USD)        129              129     129
# 7             $1 to $5 million (USD)        111              111     111
# 8           $25 to $50 million (USD)        110              110     110
# 9         Less than $1 million (USD)         93               93      93
# 10            $1 to $2 billion (USD)         87               87      87
# 11  $500 million to $1 billion (USD)         79               79      79
# 12           $5 to $10 million (USD)         72               72      72
# 13           $5 to $10 billion (USD)         56               56      56
#
#     Company_Name  Location  Headquarters  Size  Founded  Type_of_ownership  \
# 0            615       615           615   615      615                615
# 1            218       218           218   218      218                218
# 2            199       199           199   199      199                199
# 3            189       189           189   189      189                189
# 4            162       163           163   163      163                163
# 5            132       132           132   132      132                132
# 6            129       129           129   129      129                129
# 7            111       111           111   111      111                111
# 8            110       110           110   110      110                110
# 9             93        93            93    93       93                 93
# 10            87        87            87    87       87                 87
# 11            79        79            79    79       79                 79
# 12            72        72            72    72       72                 72
# 13            56        56            56    56       56                 56
#
#     ...  Sector  Competitors  Easy_Apply  Rated  Min_salary_US_K  \
# 0   ...     615          615         615    522              615
# 1   ...     218          218         218    218              218
# 2   ...     199          199         199    199              199
# 3   ...     189          189         189    189              189
# 4   ...     163          163         163      0              163
# 5   ...     132          132         132    131              132
# 6   ...     129          129         129    129              129
# 7   ...     111          111         111    101              111
# 8   ...     110          110         110    110              109
# 9   ...      93           93          93     89               93
# 10  ...      87           87          87     87               87
# 11  ...      79           79          79     79               79
# 12  ...      72           72          72     71               72
# 13  ...      56           56          56     56               56
#
#     Max_salary_US_K  Average_Salary_US_K  Location_State  Hq_state  \
# 0               615                  615             615       606
# 1               218                  218             218       218
# 2               199                  199             199       199
# 3               189                  189             189       189
# 4               163                  163             163         0
# 5               132                  132             132       132
# 6               129                  129             129       129
# 7               111                  111             111       111
# 8               110                  109             110       110
# 9                93                   93              93        93
# 10               87                   87              87        87
# 11               79                   79              79        79
# 12               72                   72              72        72
# 13               56                   56              56        56
#
#     Salary_Range
# 0            615
# 1            218
# 2            199
# 3            189
# 4            163
# 5            132
# 6            129
# 7            111
# 8            109
# 9             93
# 10            87
# 11            79
# 12            72
# 13            56
#
# [14 rows x 21 columns]

# %%
rev.Revenue.unique()
# Out:
# array(['Unknown / Non-Applicable', '$100 to $500 million (USD)',
#        '$50 to $100 million (USD)', '$10+ billion (USD)', '-1',
#        '$10 to $25 million (USD)', '$2 to $5 billion (USD)',
#        '$1 to $5 million (USD)', '$25 to $50 million (USD)',
#        'Less than $1 million (USD)', '$1 to $2 billion (USD)',
#        '$500 million to $1 billion (USD)', '$5 to $10 million (USD)',
#        '$5 to $10 billion (USD)'], dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(17, 5)
sns.barplot(x='Job_Title', y='Revenue', data= rev, orient='h', palette='summer', ci=None).set_title('No. of jobs according to the companies')
plt.xticks(rotation=90)
plt.xlabel('No.of jobs available')
plt.ylabel('Revenue')
# Out:
# Text(0, 0.5, 'Revenue')

# %% [markdown]
# Salary in large companies which has revenue more than $10+billion(USD)

# %%
lg_comp = df[df.Revenue =='$5 to $10 million (USD)']
lg_comp.sort_values(by='Rating', inplace=True)
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
lg_comp.Company_Name.unique()
# Out:
# array(['Kharon', 'Encore Consulting Services', 'CAO Group, INC',
#        'Barnabas Health', 'Economic and Community Development Institute',
#        'Infovisa, Inc.', 'Enclipse', 'Eastern Airlines LLC',
#        'VED Software Services, Inc.', 'Central Business Solutions, Inc',
#        'Occam Solutions Inc', 'GDKN', 'Infotech Sourcing', 'Numeric, LLC',
#        'Future Technologies Inc.', 'Buckeye Community Health Plan',
#        'Hexacorp', 'DatamanUSA', 'Liberty Source', 'GasPedal',
#        'ForKids, inc', 'YORKTOWN SYSTEMS GROUP INC', 'Central Health',
#        'Asembia', 'iSpace, Inc', 'Alexza Pharmaceuticals',
#        'Login Consulting Services, Inc', 'Login Consulting Services',
#        'RiverPoint', 'Odesus', 'Edmodo', 'SOFTHQ INC', 'SACC', 'Zipongo',
#        'Lightbeam Health Solutions', 'BayOne Solutions',
#        'Source of Future Technology Inc', 'VSE, Inc.',
#        'SkySource Solutions', 'V R Della Infotech Inc',
#        'Hearst Television, Inc', 'MVP Consulting Plus Inc',
#        '22nd Century Staffing', 'Alliance IT', 'Apptricity Corporation',
#        'RAMPS International Inc', 'Resource Informatics Group',
#        'Conch Technologies, Inc', 'Financial Additions',
#        'Motiv Power Systems', 'MIRACORP', 'PCR Staffing',
#        'xentity corporation', 'Crossfire Consulting Corporation'],
#       dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(20, 10)
sns.barplot(x= 'Company_Name', y='Average_Salary_US_K', data=lg_comp, palette='cool', ci=None, hue='Rated', dodge=False)
plt.title("Salary of the large companies\n Revenue more than $10 million (USD)")
plt.xticks(rotation=90)
plt.xlabel('Company name')
plt.ylabel('Average Salary')
# Out:
# Text(0, 0.5, 'Average Salary')

# %%
df.Sector.unique()
# Out:
# array(['Non-Profit', 'Health Care', 'Information Technology',
#        'Arts, Entertainment & Recreation', 'Finance', 'Insurance',
#        'Business Services', '-1', 'Restaurants, Bars & Food Services',
#        'Media', 'Accounting & Legal', 'Real Estate', 'Government',
#        'Retail', 'Consumer Services', 'Biotech & Pharmaceuticals',
#        'Education', 'Construction, Repair & Maintenance',
#        'Oil, Gas, Energy & Utilities', 'Manufacturing',
#        'Aerospace & Defense', 'Telecommunications',
#        'Transportation & Logistics', 'Mining & Metals',
#        'Travel & Tourism'], dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(15, 7)
sns.swarmplot(y='Sector', x='Average_Salary_US_K', data=df, hue='Rated', palette='winter', orient='h').set_title('Salary across the sectors')
plt.xlabel('Average salary')
plt.ylabel('Sectors')
plt.xticks(rotation=90)
plt.legend(loc='upper left',bbox_to_anchor=(1,1));
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 35.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 74.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 39.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 5.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 72.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 29.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 23.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 13.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
fig = plt.gcf()
fig.set_size_inches(15, 7)
sns.distplot(df.Founded, color= 'r')
# Out:
# /Users/nithish02/opt/miniconda3/envs/minimal_ds2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Founded', ylabel='Density'>

# %%
fig = plt.gcf()
fig.set_size_inches(15, 7)
sns.kdeplot(df.Min_salary_US_K, color='r', shade=True)
sns.kdeplot(df.Max_salary_US_K, color='g',shade=True)
sns.kdeplot(df.Average_Salary_US_K, color='b',shade=True)
plt.xlabel("Salary")
plt.legend(["Min salary", "Max salary", "Average salary"])

# %%
india = df[df.Hq_state == ' India']
india.Company_Name.unique()
# Out:
# array(['Cactus Holdings', 'EVMS', 'WB Technology', 'INSPIRE IT Solutions',
#        'Easyfind Company', 'InvenTech Info', 'HCL Technologies Ltd.',
#        'L&T Infotech', 'Corporate G. LLC', 'HCL America Inc.', 'Mindteck',
#        'Calsoft Labs', 'Lean Data', 'Tata Consultancy Services',
#        'SigmaWay', 'Saama', 'Subex', 'Wipro Ltd.',
#        'Zen3 Infosolutions America Inc', 'CitiusTech'], dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(15, 7)
sns.barplot(x='Size', y= 'Average_Salary_US_K', data=india, hue='Rated', ci=None ,palette=['#e9e35a','#ffa200','#00bd13','#0080ff']).set_title('Available jobs accordig in their size of the company')
plt.xticks(rotation=80)
plt.xlabel('size of the company')
plt.ylabel('average salary')
# Out:
# Text(0, 0.5, 'average salary')

# %%
fig = plt.gcf()
fig.set_size_inches(15, 7)
sns.regplot(x='Average_Salary_US_K', y="Rating",data=df,marker='+', color='red').set_title("correlation between salary and rating")
plt.xlabel("Average salary")
# Out:
# Text(0.5, 0, 'Average salary')

# %% [markdown]
# There is a correlation but not a significant linear line
